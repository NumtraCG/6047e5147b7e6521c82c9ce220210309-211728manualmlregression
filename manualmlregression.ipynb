# %% [markdown]
# ***GENERATED CODE FOR manualmlregression PIPELINE.***

# %% [markdown]
# ***DON'T EDIT THIS CODE.***

# %% [markdown]
# ***CONNECTOR FUNCTIONS TO READ DATA.***

# %% [markdown]
# ***AUTOML FUNCTIONS***

# %% [markdown]
# ***READING DATAFRAME***

# %%
#%run manualmlregressionHooks.ipynb
try:
	
except Exception as ex: 
	logging.error(ex)

# %% [markdown]
# ***TRAIN MODEL***

# %%
#%run manualmlregressionHooks.ipynb
try:
	#mlPreExecutionHook()

	dataAutoML=XG-Boost-classifier(manualfe, ["CRIM", "INDUS", "NOX", "RM", "AGE", "DIS", "TAX", "PTRATIO", "B", "LSTAT", "ZN_stringindexer", "CHAS_stringindexer", "RAD_stringindexer"], "MEDV")

	#mlPostExecutionHook(dataAutoML)

except Exception as ex: 
	logging.error(ex)
